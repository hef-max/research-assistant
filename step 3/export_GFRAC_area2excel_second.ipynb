# %%
import pandas as pd
import numpy as np
import xarray
from functools import reduce

# %%
# gfrac_areav2 = xarray.open_dataset("D:/kerja/asisten riset/vol/milkunC/achaidir/IMAGE PBL/SSP2/total_emisi_percrops_netcdf.nc", engine="netcdf4")
# gfrac_ngfbfc = [element.strip() for element in gfrac_area.coords['NGFBFC'].data.astype('str').tolist()]
gfrac_areav2 = xarray.open_dataset("D:/kerja/asisten riset/vol/milkunC/achaidir/IMAGE PBL/SSP2/GFRAC_areav2.nc", engine="netcdf4")

# %%
irWheat = gfrac_areav2['IR Wheat']
irRice = gfrac_areav2['IR Rice']
irMaize = gfrac_areav2['IR Maize']
irTropical = gfrac_areav2['IR Tropical cereals']
irOthertemperatecereals = gfrac_areav2['IR Other temperate cereals']
irPulses = gfrac_areav2['IR Pulses']
irSoybeans = gfrac_areav2['IR Soybeans']
irTemperateoilcrops = gfrac_areav2['IR Temperate oil crops']
irTropicaloilcrops = gfrac_areav2['IR Tropical oil crops']
irTemperaterootstubers = gfrac_areav2['IR Temperate roots & tubers']
irTropicalrootstubers = gfrac_areav2['IR Tropical roots & tubers']
irSugarcrops = gfrac_areav2['IR Sugar crops']
irOilpalmfruit = gfrac_areav2['IR Oil & palm fruit']
irVegetablesfruits = gfrac_areav2['IR Vegetables & fruits']
irOthernonfooduxuryspices = gfrac_areav2['IR Other non-food & luxury & spices']
irPlantbasedfibres = gfrac_areav2['IR Plant based fibres']

rfWheat = gfrac_areav2['RF Wheat']
rfRice = gfrac_areav2['RF Rice']
rfMaize = gfrac_areav2['RF Maize']
rfTropical = gfrac_areav2['RF Tropical cereals']
rfOthertemperatecereals = gfrac_areav2['RF Other temperate cereals']
rfPulses = gfrac_areav2['RF Pulses']
rfSoybeans = gfrac_areav2['RF Soybeans']
rfTemperateoilcrops = gfrac_areav2['RF Temperate oil crops']
rfTropicaloilcrops = gfrac_areav2['RF Tropical oil crops']
rfTemperaterootstubers = gfrac_areav2['RF Temperate roots & tubers']
rfTropicalrootstubers = gfrac_areav2['RF Tropical roots & tubers']
rfSugarcrops = gfrac_areav2['RF Sugar crops']
rfOilpalmfruit = gfrac_areav2['RF Oil & palm fruit']
rfVegetablesfruits = gfrac_areav2['RF Vegetables & fruits']
rfOthernonfooduxuryspices = gfrac_areav2['RF Other non-food & luxury & spices']
rfPlantbasedfibres = gfrac_areav2['RF Plant based fibres']

# %%
df = irWheat.isel(time=0).to_dataframe()
df1 = irWheat.isel(time=1).to_dataframe()
df2 = irWheat.isel(time=2).to_dataframe()
df3 = irWheat.isel(time=3).to_dataframe()
df4 = irWheat.isel(time=4).to_dataframe()
df5 = irWheat.isel(time=5).to_dataframe()
df6 = irWheat.isel(time=6).to_dataframe()
df7 = irWheat.isel(time=7).to_dataframe()
df8 = irWheat.isel(time=8).to_dataframe()
df9 = irWheat.isel(time=9).to_dataframe()
df10 = irWheat.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
df_index2.columns = data2.year
data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
df_index3.columns = data3.year
data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
df_index4.columns = data4.year
data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
df_index5.columns = data5.year
data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
df_index6.columns = data6.year
data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
df_index7.columns = data7.year
data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
df_index8.columns = data8.year
data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
df_index9.columns = data9.year
data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
df_index2 = df_index2.reset_index()
df_index3 = df_index3.reset_index()
df_index4 = df_index4.reset_index()
df_index5 = df_index5.reset_index()
df_index6 = df_index6.reset_index()
df_index7 = df_index7.reset_index()
df_index8 = df_index8.reset_index()
df_index9 = df_index9.reset_index()
df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
df_index2.rename(columns={'level_1': "type"}, inplace=True)
df_index3.rename(columns={'level_1': "type"}, inplace=True)
df_index4.rename(columns={'level_1': "type"}, inplace=True)
df_index5.rename(columns={'level_1': "type"}, inplace=True)
df_index6.rename(columns={'level_1': "type"}, inplace=True)
df_index7.rename(columns={'level_1': "type"}, inplace=True)
df_index8.rename(columns={'level_1': "type"}, inplace=True)
df_index9.rename(columns={'level_1': "type"}, inplace=True)
df_index10.rename(columns={'level_1': "type"}, inplace=True)

frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
# frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irWheat_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irWheat_df = irWheat_df.replace([np.inf, -np.inf], np.nan)
irWheat_df = irWheat_df.fillna(0)

# %%
df = rfWheat.isel(time=0).to_dataframe()
df1 = rfWheat.isel(time=1).to_dataframe()
# df2 = rfWheat.isel(time=2).to_dataframe()
# df3 = rfWheat.isel(time=3).to_dataframe()
# df4 = rfWheat.isel(time=4).to_dataframe()
# df5 = rfWheat.isel(time=5).to_dataframe()
# df6 = rfWheat.isel(time=6).to_dataframe()
# df7 = rfWheat.isel(time=7).to_dataframe()
# df8 = rfWheat.isel(time=8).to_dataframe()
# df9 = rfWheat.isel(time=9).to_dataframe()
# df10 = rfWheat.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfWheat_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfWheat_df = rfWheat_df.replace([np.inf, -np.inf], np.nan)
rfWheat_df = rfWheat_df.fillna(0)

# %%
df = irRice.isel(time=0).to_dataframe()
df1 = irRice.isel(time=1).to_dataframe()
# df2 = irRice.isel(time=2).to_dataframe()
# df3 = irRice.isel(time=3).to_dataframe()
# df4 = irRice.isel(time=4).to_dataframe()
# df5 = irRice.isel(time=5).to_dataframe()
# df6 = irRice.isel(time=6).to_dataframe()
# df7 = irRice.isel(time=7).to_dataframe()
# df8 = irRice.isel(time=8).to_dataframe()
# df9 = irRice.isel(time=9).to_dataframe()
# df10 = irRice.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irRice_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irRice_df = irRice_df.replace([np.inf, -np.inf], np.nan)
irRice_df = irRice_df.fillna(0)

# %%
df = rfRice.isel(time=0).to_dataframe()
df1 = rfRice.isel(time=1).to_dataframe()
# df2 = rfRice.isel(time=2).to_dataframe()
# df3 = rfRice.isel(time=3).to_dataframe()
# df4 = rfRice.isel(time=4).to_dataframe()
# df5 = rfRice.isel(time=5).to_dataframe()
# df6 = rfRice.isel(time=6).to_dataframe()
# df7 = rfRice.isel(time=7).to_dataframe()
# df8 = rfRice.isel(time=8).to_dataframe()
# df9 = rfRice.isel(time=9).to_dataframe()
# df10 = rfRice.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfRice_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfRice_df = rfRice_df.replace([np.inf, -np.inf], np.nan)
rfRice_df = rfRice_df.fillna(0)

# %%
df = irMaize.isel(time=0).to_dataframe()
df1 = irMaize.isel(time=1).to_dataframe()
# df2 = irMaize.isel(time=2).to_dataframe()
# df3 = irMaize.isel(time=3).to_dataframe()
# df4 = irMaize.isel(time=4).to_dataframe()
# df5 = irMaize.isel(time=5).to_dataframe()
# df6 = irMaize.isel(time=6).to_dataframe()
# df7 = irMaize.isel(time=7).to_dataframe()
# df8 = irMaize.isel(time=8).to_dataframe()
# df9 = irMaize.isel(time=9).to_dataframe()
# df10 = irMaize.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irMaize_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irMaize_df = irMaize_df.replace([np.inf, -np.inf], np.nan)
irMaize_df = irMaize_df.fillna(0)

# %%
df = rfMaize.isel(time=0).to_dataframe()
df1 = rfMaize.isel(time=1).to_dataframe()
# df2 = rfMaize.isel(time=2).to_dataframe()
# df3 = rfMaize.isel(time=3).to_dataframe()
# df4 = rfMaize.isel(time=4).to_dataframe()
# df5 = rfMaize.isel(time=5).to_dataframe()
# df6 = rfMaize.isel(time=6).to_dataframe()
# df7 = rfMaize.isel(time=7).to_dataframe()
# df8 = rfMaize.isel(time=8).to_dataframe()
# df9 = rfMaize.isel(time=9).to_dataframe()
# df10 = rfMaize.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfMaize_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfMaize_df = rfMaize_df.replace([np.inf, -np.inf], np.nan)
rfMaize_df = rfMaize_df.fillna(0)

# %%
df = irTropical.isel(time=0).to_dataframe()
df1 = irTropical.isel(time=1).to_dataframe()
# df2 = irTropical.isel(time=2).to_dataframe()
# df3 = irTropical.isel(time=3).to_dataframe()
# df4 = irTropical.isel(time=4).to_dataframe()
# df5 = irTropical.isel(time=5).to_dataframe()
# df6 = irTropical.isel(time=6).to_dataframe()
# df7 = irTropical.isel(time=7).to_dataframe()
# df8 = irTropical.isel(time=8).to_dataframe()
# df9 = irTropical.isel(time=9).to_dataframe()
# df10 = irTropical.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irTropical_cereals_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irTropical_cereals_df = irTropical_cereals_df.replace([np.inf, -np.inf], np.nan)
irTropical_cereals_df = irTropical_cereals_df.fillna(0)

# %%
df = rfTropical.isel(time=0).to_dataframe()
df1 = rfTropical.isel(time=1).to_dataframe()
# df2 = rfTropical.isel(time=2).to_dataframe()
# df3 = rfTropical.isel(time=3).to_dataframe()
# df4 = rfTropical.isel(time=4).to_dataframe()
# df5 = rfTropical.isel(time=5).to_dataframe()
# df6 = rfTropical.isel(time=6).to_dataframe()
# df7 = rfTropical.isel(time=7).to_dataframe()
# df8 = rfTropical.isel(time=8).to_dataframe()
# df9 = rfTropical.isel(time=9).to_dataframe()
# df10 = rfTropical.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfTropical_cereals_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfTropical_cereals_df = rfTropical_cereals_df.replace([np.inf, -np.inf], np.nan)
rfTropical_cereals_df = rfTropical_cereals_df.fillna(0)

# %%
df = irOthertemperatecereals.isel(time=0).to_dataframe()
df1 = irOthertemperatecereals.isel(time=1).to_dataframe()
# df2 = irOthertemperatecereals.isel(time=2).to_dataframe()
# df3 = irOthertemperatecereals.isel(time=3).to_dataframe()
# df4 = irOthertemperatecereals.isel(time=4).to_dataframe()
# df5 = irOthertemperatecereals.isel(time=5).to_dataframe()
# df6 = irOthertemperatecereals.isel(time=6).to_dataframe()
# df7 = irOthertemperatecereals.isel(time=7).to_dataframe()
# df8 = irOthertemperatecereals.isel(time=8).to_dataframe()
# df9 = irOthertemperatecereals.isel(time=9).to_dataframe()
# df10 = irOthertemperatecereals.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irOthertemperatecereals_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irOthertemperatecereals_df = irOthertemperatecereals_df.replace([np.inf, -np.inf], np.nan)
irOthertemperatecereals_df = irOthertemperatecereals_df.fillna(0)

# %%
df = rfOthertemperatecereals.isel(time=0).to_dataframe()
df1 = rfOthertemperatecereals.isel(time=1).to_dataframe()
# df2 = rfOthertemperatecereals.isel(time=2).to_dataframe()
# df3 = rfOthertemperatecereals.isel(time=3).to_dataframe()
# df4 = rfOthertemperatecereals.isel(time=4).to_dataframe()
# df5 = rfOthertemperatecereals.isel(time=5).to_dataframe()
# df6 = rfOthertemperatecereals.isel(time=6).to_dataframe()
# df7 = rfOthertemperatecereals.isel(time=7).to_dataframe()
# df8 = rfOthertemperatecereals.isel(time=8).to_dataframe()
# df9 = rfOthertemperatecereals.isel(time=9).to_dataframe()
# df10 = rfOthertemperatecereals.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfOthertemperatecereals_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfOthertemperatecereals_df = rfOthertemperatecereals_df.replace([np.inf, -np.inf], np.nan)
rfOthertemperatecereals_df = rfOthertemperatecereals_df.fillna(0)

# %%
df = irPulses.isel(time=0).to_dataframe()
df1 = irPulses.isel(time=1).to_dataframe()
# df2 = irPulses.isel(time=2).to_dataframe()
# df3 = irPulses.isel(time=3).to_dataframe()
# df4 = irPulses.isel(time=4).to_dataframe()
# df5 = irPulses.isel(time=5).to_dataframe()
# df6 = irPulses.isel(time=6).to_dataframe()
# df7 = irPulses.isel(time=7).to_dataframe()
# df8 = irPulses.isel(time=8).to_dataframe()
# df9 = irPulses.isel(time=9).to_dataframe()
# df10 = irPulses.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irPulses_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irPulses_df = irPulses_df.replace([np.inf, -np.inf], np.nan)
irPulses_df = irPulses_df.fillna(0)

# %%
df = rfPulses.isel(time=0).to_dataframe()
df1 = rfPulses.isel(time=1).to_dataframe()
# df2 = rfPulses.isel(time=2).to_dataframe()
# df3 = rfPulses.isel(time=3).to_dataframe()
# df4 = rfPulses.isel(time=4).to_dataframe()
# df5 = rfPulses.isel(time=5).to_dataframe()
# df6 = rfPulses.isel(time=6).to_dataframe()
# df7 = rfPulses.isel(time=7).to_dataframe()
# df8 = rfPulses.isel(time=8).to_dataframe()
# df9 = rfPulses.isel(time=9).to_dataframe()
# df10 = rfPulses.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfPulses_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfPulses_df = rfPulses_df.replace([np.inf, -np.inf], np.nan)
rfPulses_df = rfPulses_df.fillna(0)

# %%
df = irSoybeans.isel(time=0).to_dataframe()
df1 = irSoybeans.isel(time=1).to_dataframe()
# df2 = irSoybeans.isel(time=2).to_dataframe()
# df3 = irSoybeans.isel(time=3).to_dataframe()
# df4 = irSoybeans.isel(time=4).to_dataframe()
# df5 = irSoybeans.isel(time=5).to_dataframe()
# df6 = irSoybeans.isel(time=6).to_dataframe()
# df7 = irSoybeans.isel(time=7).to_dataframe()
# df8 = irSoybeans.isel(time=8).to_dataframe()
# df9 = irSoybeans.isel(time=9).to_dataframe()
# df10 = irSoybeans.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irSoybeans_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irSoybeans_df = irSoybeans_df.replace([np.inf, -np.inf], np.nan)
irSoybeans_df = irSoybeans_df.fillna(0)

# %%
df = rfSoybeans.isel(time=0).to_dataframe()
df1 = rfSoybeans.isel(time=1).to_dataframe()
# df2 = rfSoybeans.isel(time=2).to_dataframe()
# df3 = rfSoybeans.isel(time=3).to_dataframe()
# df4 = rfSoybeans.isel(time=4).to_dataframe()
# df5 = rfSoybeans.isel(time=5).to_dataframe()
# df6 = rfSoybeans.isel(time=6).to_dataframe()
# df7 = rfSoybeans.isel(time=7).to_dataframe()
# df8 = rfSoybeans.isel(time=8).to_dataframe()
# df9 = rfSoybeans.isel(time=9).to_dataframe()
# df10 = rfSoybeans.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfSoybeans_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfSoybeans_df = rfSoybeans_df.replace([np.inf, -np.inf], np.nan)
rfSoybeans_df = rfSoybeans_df.fillna(0)

# %%
df = irTemperateoilcrops.isel(time=0).to_dataframe()
df1 = irTemperateoilcrops.isel(time=1).to_dataframe()
# df2 = irTemperateoilcrops.isel(time=2).to_dataframe()
# df3 = irTemperateoilcrops.isel(time=3).to_dataframe()
# df4 = irTemperateoilcrops.isel(time=4).to_dataframe()
# df5 = irTemperateoilcrops.isel(time=5).to_dataframe()
# df6 = irTemperateoilcrops.isel(time=6).to_dataframe()
# df7 = irTemperateoilcrops.isel(time=7).to_dataframe()
# df8 = irTemperateoilcrops.isel(time=8).to_dataframe()
# df9 = irTemperateoilcrops.isel(time=9).to_dataframe()
# df10 = irTemperateoilcrops.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irTemperateoilcrops_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irTemperateoilcrops_df = irTemperateoilcrops_df.replace([np.inf, -np.inf], np.nan)
irTemperateoilcrops_df = irTemperateoilcrops_df.fillna(0)

# %%
df = rfTemperateoilcrops.isel(time=0).to_dataframe()
df1 = rfTemperateoilcrops.isel(time=1).to_dataframe()
# df2 = rfTemperateoilcrops.isel(time=2).to_dataframe()
# df3 = rfTemperateoilcrops.isel(time=3).to_dataframe()
# df4 = rfTemperateoilcrops.isel(time=4).to_dataframe()
# df5 = rfTemperateoilcrops.isel(time=5).to_dataframe()
# df6 = rfTemperateoilcrops.isel(time=6).to_dataframe()
# df7 = rfTemperateoilcrops.isel(time=7).to_dataframe()
# df8 = rfTemperateoilcrops.isel(time=8).to_dataframe()
# df9 = rfTemperateoilcrops.isel(time=9).to_dataframe()
# df10 = rfTemperateoilcrops.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfTemperateoilcrops_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfTemperateoilcrops_df = rfTemperateoilcrops_df.replace([np.inf, -np.inf], np.nan)
rfTemperateoilcrops_df = rfTemperateoilcrops_df.fillna(0)

# %%
df = irTropicaloilcrops.isel(time=0).to_dataframe()
df1 = irTropicaloilcrops.isel(time=1).to_dataframe()
# df2 = irTropicaloilcrops.isel(time=2).to_dataframe()
# df3 = irTropicaloilcrops.isel(time=3).to_dataframe()
# df4 = irTropicaloilcrops.isel(time=4).to_dataframe()
# df5 = irTropicaloilcrops.isel(time=5).to_dataframe()
# df6 = irTropicaloilcrops.isel(time=6).to_dataframe()
# df7 = irTropicaloilcrops.isel(time=7).to_dataframe()
# df8 = irTropicaloilcrops.isel(time=8).to_dataframe()
# df9 = irTropicaloilcrops.isel(time=9).to_dataframe()
# df10 = irTropicaloilcrops.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irTropicaloilcrops_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irTropicaloilcrops_df = irTropicaloilcrops_df.replace([np.inf, -np.inf], np.nan)
irTropicaloilcrops_df = irTropicaloilcrops_df.fillna(0)

# %%
df = rfTropicaloilcrops.isel(time=0).to_dataframe()
df1 = rfTropicaloilcrops.isel(time=1).to_dataframe()
# df2 = rfTropicaloilcrops.isel(time=2).to_dataframe()
# df3 = rfTropicaloilcrops.isel(time=3).to_dataframe()
# df4 = rfTropicaloilcrops.isel(time=4).to_dataframe()
# df5 = rfTropicaloilcrops.isel(time=5).to_dataframe()
# df6 = rfTropicaloilcrops.isel(time=6).to_dataframe()
# df7 = rfTropicaloilcrops.isel(time=7).to_dataframe()
# df8 = rfTropicaloilcrops.isel(time=8).to_dataframe()
# df9 = rfTropicaloilcrops.isel(time=9).to_dataframe()
# df10 = rfTropicaloilcrops.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfTropicaloilcrops_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfTropicaloilcrops_df = rfTropicaloilcrops_df.replace([np.inf, -np.inf], np.nan)
rfTropicaloilcrops_df = rfTropicaloilcrops_df.fillna(0)

# %%
df = irTemperaterootstubers.isel(time=0).to_dataframe()
df1 = irTemperaterootstubers.isel(time=1).to_dataframe()
# df2 = irTemperaterootstubers.isel(time=2).to_dataframe()
# df3 = irTemperaterootstubers.isel(time=3).to_dataframe()
# df4 = irTemperaterootstubers.isel(time=4).to_dataframe()
# df5 = irTemperaterootstubers.isel(time=5).to_dataframe()
# df6 = irTemperaterootstubers.isel(time=6).to_dataframe()
# df7 = irTemperaterootstubers.isel(time=7).to_dataframe()
# df8 = irTemperaterootstubers.isel(time=8).to_dataframe()
# df9 = irTemperaterootstubers.isel(time=9).to_dataframe()
# df10 = irTemperaterootstubers.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]
# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irTemperaterootstubers_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irTemperaterootstubers_df = irTemperaterootstubers_df.replace([np.inf, -np.inf], np.nan)
irTemperaterootstubers_df = irTemperaterootstubers_df.fillna(0)

# %%
df = rfTemperaterootstubers.isel(time=0).to_dataframe()
df1 = rfTemperaterootstubers.isel(time=1).to_dataframe()
# df2 = rfTemperaterootstubers.isel(time=2).to_dataframe()
# df3 = rfTemperaterootstubers.isel(time=3).to_dataframe()
# df4 = rfTemperaterootstubers.isel(time=4).to_dataframe()
# df5 = rfTemperaterootstubers.isel(time=5).to_dataframe()
# df6 = rfTemperaterootstubers.isel(time=6).to_dataframe()
# df7 = rfTemperaterootstubers.isel(time=7).to_dataframe()
# df8 = rfTemperaterootstubers.isel(time=8).to_dataframe()
# df9 = rfTemperaterootstubers.isel(time=9).to_dataframe()
# df10 = rfTemperaterootstubers.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]
# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfTemperaterootstubers_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfTemperaterootstubers_df = rfTemperaterootstubers_df.replace([np.inf, -np.inf], np.nan)
rfTemperaterootstubers_df = rfTemperaterootstubers_df.fillna(0)

# %%
df = irTropicalrootstubers.isel(time=0).to_dataframe()
df1 = irTropicalrootstubers.isel(time=1).to_dataframe()
# df2 = irTropicalrootstubers.isel(time=2).to_dataframe()
# df3 = irTropicalrootstubers.isel(time=3).to_dataframe()
# df4 = irTropicalrootstubers.isel(time=4).to_dataframe()
# df5 = irTropicalrootstubers.isel(time=5).to_dataframe()
# df6 = irTropicalrootstubers.isel(time=6).to_dataframe()
# df7 = irTropicalrootstubers.isel(time=7).to_dataframe()
# df8 = irTropicalrootstubers.isel(time=8).to_dataframe()
# df9 = irTropicalrootstubers.isel(time=9).to_dataframe()
# df10 = irTropicalrootstubers.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irTropicalrootstubers_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irTropicalrootstubers_df = irTropicalrootstubers_df.replace([np.inf, -np.inf], np.nan)
irTropicalrootstubers_df = irTropicalrootstubers_df.fillna(0)

# %%
df = rfTropicalrootstubers.isel(time=0).to_dataframe()
df1 = rfTropicalrootstubers.isel(time=1).to_dataframe()
# df2 = rfTropicalrootstubers.isel(time=2).to_dataframe()
# df3 = rfTropicalrootstubers.isel(time=3).to_dataframe()
# df4 = rfTropicalrootstubers.isel(time=4).to_dataframe()
# df5 = rfTropicalrootstubers.isel(time=5).to_dataframe()
# df6 = rfTropicalrootstubers.isel(time=6).to_dataframe()
# df7 = rfTropicalrootstubers.isel(time=7).to_dataframe()
# df8 = rfTropicalrootstubers.isel(time=8).to_dataframe()
# df9 = rfTropicalrootstubers.isel(time=9).to_dataframe()
# df10 = rfTropicalrootstubers.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfTropicalrootstubers_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfTropicalrootstubers_df = rfTropicalrootstubers_df.replace([np.inf, -np.inf], np.nan)
rfTropicalrootstubers_df = rfTropicalrootstubers_df.fillna(0)

# %%
df = irSugarcrops.isel(time=0).to_dataframe()
df1 = irSugarcrops.isel(time=1).to_dataframe()
# df2 = irSugarcrops.isel(time=2).to_dataframe()
# df3 = irSugarcrops.isel(time=3).to_dataframe()
# df4 = irSugarcrops.isel(time=4).to_dataframe()
# df5 = irSugarcrops.isel(time=5).to_dataframe()
# df6 = irSugarcrops.isel(time=6).to_dataframe()
# df7 = irSugarcrops.isel(time=7).to_dataframe()
# df8 = irSugarcrops.isel(time=8).to_dataframe()
# df9 = irSugarcrops.isel(time=9).to_dataframe()
# df10 = irSugarcrops.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irSugarcrops_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irSugarcrops_df = irSugarcrops_df.replace([np.inf, -np.inf], np.nan)
irSugarcrops_df = irSugarcrops_df.fillna(0)

# %%
df = rfSugarcrops.isel(time=0).to_dataframe()
df1 = rfSugarcrops.isel(time=1).to_dataframe()
# df2 = rfSugarcrops.isel(time=2).to_dataframe()
# df3 = rfSugarcrops.isel(time=3).to_dataframe()
# df4 = rfSugarcrops.isel(time=4).to_dataframe()
# df5 = rfSugarcrops.isel(time=5).to_dataframe()
# df6 = rfSugarcrops.isel(time=6).to_dataframe()
# df7 = rfSugarcrops.isel(time=7).to_dataframe()
# df8 = rfSugarcrops.isel(time=8).to_dataframe()
# df9 = rfSugarcrops.isel(time=9).to_dataframe()
# df10 = rfSugarcrops.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfSugarcrops_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfSugarcrops_df = rfSugarcrops_df.replace([np.inf, -np.inf], np.nan)
rfSugarcrops_df = rfSugarcrops_df.fillna(0)

# %%
df = irOilpalmfruit.isel(time=0).to_dataframe()
df1 = irOilpalmfruit.isel(time=1).to_dataframe()
# df2 = irOilpalmfruit.isel(time=2).to_dataframe()
# df3 = irOilpalmfruit.isel(time=3).to_dataframe()
# df4 = irOilpalmfruit.isel(time=4).to_dataframe()
# df5 = irOilpalmfruit.isel(time=5).to_dataframe()
# df6 = irOilpalmfruit.isel(time=6).to_dataframe()
# df7 = irOilpalmfruit.isel(time=7).to_dataframe()
# df8 = irOilpalmfruit.isel(time=8).to_dataframe()
# df9 = irOilpalmfruit.isel(time=9).to_dataframe()
# df10 = irOilpalmfruit.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irOilpalmfruit_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irOilpalmfruit_df = irOilpalmfruit_df.replace([np.inf, -np.inf], np.nan)
irOilpalmfruit_df = irOilpalmfruit_df.fillna(0)

# %%
df = rfOilpalmfruit.isel(time=0).to_dataframe()
df1 = rfOilpalmfruit.isel(time=1).to_dataframe()
# df2 = rfOilpalmfruit.isel(time=2).to_dataframe()
# df3 = rfOilpalmfruit.isel(time=3).to_dataframe()
# df4 = rfOilpalmfruit.isel(time=4).to_dataframe()
# df5 = rfOilpalmfruit.isel(time=5).to_dataframe()
# df6 = rfOilpalmfruit.isel(time=6).to_dataframe()
# df7 = rfOilpalmfruit.isel(time=7).to_dataframe()
# df8 = rfOilpalmfruit.isel(time=8).to_dataframe()
# df9 = rfOilpalmfruit.isel(time=9).to_dataframe()
# df10 = rfOilpalmfruit.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfOilpalmfruit_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfOilpalmfruit_df = rfOilpalmfruit_df.replace([np.inf, -np.inf], np.nan)
rfOilpalmfruit_df = rfOilpalmfruit_df.fillna(0)

# %%
df = irVegetablesfruits.isel(time=0).to_dataframe()
df1 = irVegetablesfruits.isel(time=1).to_dataframe()
# df2 = irVegetablesfruits.isel(time=2).to_dataframe()
# df3 = irVegetablesfruits.isel(time=3).to_dataframe()
# df4 = irVegetablesfruits.isel(time=4).to_dataframe()
# df5 = irVegetablesfruits.isel(time=5).to_dataframe()
# df6 = irVegetablesfruits.isel(time=6).to_dataframe()
# df7 = irVegetablesfruits.isel(time=7).to_dataframe()
# df8 = irVegetablesfruits.isel(time=8).to_dataframe()
# df9 = irVegetablesfruits.isel(time=9).to_dataframe()
# df10 = irVegetablesfruits.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irVegetablesfruits_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irVegetablesfruits_df = irVegetablesfruits_df.replace([np.inf, -np.inf], np.nan)
irVegetablesfruits_df = irVegetablesfruits_df.fillna(0)

# %%
df = rfVegetablesfruits.isel(time=0).to_dataframe()
df1 = rfVegetablesfruits.isel(time=1).to_dataframe()
# df2 = rfVegetablesfruits.isel(time=2).to_dataframe()
# df3 = rfVegetablesfruits.isel(time=3).to_dataframe()
# df4 = rfVegetablesfruits.isel(time=4).to_dataframe()
# df5 = rfVegetablesfruits.isel(time=5).to_dataframe()
# df6 = rfVegetablesfruits.isel(time=6).to_dataframe()
# df7 = rfVegetablesfruits.isel(time=7).to_dataframe()
# df8 = rfVegetablesfruits.isel(time=8).to_dataframe()
# df9 = rfVegetablesfruits.isel(time=9).to_dataframe()
# df10 = rfVegetablesfruits.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfVegetablesfruits_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfVegetablesfruits_df = rfVegetablesfruits_df.replace([np.inf, -np.inf], np.nan)
rfVegetablesfruits_df = rfVegetablesfruits_df.fillna(0)

# %%
df = irOthernonfooduxuryspices.isel(time=0).to_dataframe()
df1 = irOthernonfooduxuryspices.isel(time=1).to_dataframe()
# df2 = irOthernonfooduxuryspices.isel(time=2).to_dataframe()
# df3 = irOthernonfooduxuryspices.isel(time=3).to_dataframe()
# df4 = irOthernonfooduxuryspices.isel(time=4).to_dataframe()
# df5 = irOthernonfooduxuryspices.isel(time=5).to_dataframe()
# df6 = irOthernonfooduxuryspices.isel(time=6).to_dataframe()
# df7 = irOthernonfooduxuryspices.isel(time=7).to_dataframe()
# df8 = irOthernonfooduxuryspices.isel(time=8).to_dataframe()
# df9 = irOthernonfooduxuryspices.isel(time=9).to_dataframe()
# df10 = irOthernonfooduxuryspices.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]
# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irOthernonfooduxuryspices_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irOthernonfooduxuryspices_df = irOthernonfooduxuryspices_df.replace([np.inf, -np.inf], np.nan)
irOthernonfooduxuryspices_df = irOthernonfooduxuryspices_df.fillna(0)

# %%
df = rfOthernonfooduxuryspices.isel(time=0).to_dataframe()
df1 = rfOthernonfooduxuryspices.isel(time=1).to_dataframe()
# df2 = rfOthernonfooduxuryspices.isel(time=2).to_dataframe()
# df3 = rfOthernonfooduxuryspices.isel(time=3).to_dataframe()
# df4 = rfOthernonfooduxuryspices.isel(time=4).to_dataframe()
# df5 = rfOthernonfooduxuryspices.isel(time=5).to_dataframe()
# df6 = rfOthernonfooduxuryspices.isel(time=6).to_dataframe()
# df7 = rfOthernonfooduxuryspices.isel(time=7).to_dataframe()
# df8 = rfOthernonfooduxuryspices.isel(time=8).to_dataframe()
# df9 = rfOthernonfooduxuryspices.isel(time=9).to_dataframe()
# df10 = rfOthernonfooduxuryspices.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfOthernonfooduxuryspices_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfOthernonfooduxuryspices_df = rfOthernonfooduxuryspices_df.replace([np.inf, -np.inf], np.nan)
rfOthernonfooduxuryspices_df = rfOthernonfooduxuryspices_df.fillna(0)

# %%
df = irPlantbasedfibres.isel(time=0).to_dataframe()
df1 = irPlantbasedfibres.isel(time=1).to_dataframe()
# df2 = irPlantbasedfibres.isel(time=2).to_dataframe()
# df3 = irPlantbasedfibres.isel(time=3).to_dataframe()
# df4 = irPlantbasedfibres.isel(time=4).to_dataframe()
# df5 = irPlantbasedfibres.isel(time=5).to_dataframe()
# df6 = irPlantbasedfibres.isel(time=6).to_dataframe()
# df7 = irPlantbasedfibres.isel(time=7).to_dataframe()
# df8 = irPlantbasedfibres.isel(time=8).to_dataframe()
# df9 = irPlantbasedfibres.isel(time=9).to_dataframe()
# df10 = irPlantbasedfibres.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]

# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
irPlantbasedfibres_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
irPlantbasedfibres_df = irPlantbasedfibres_df.replace([np.inf, -np.inf], np.nan)
irPlantbasedfibres_df = irPlantbasedfibres_df.fillna(0)

# %%
df = rfPlantbasedfibres.isel(time=0).to_dataframe()
df1 = rfPlantbasedfibres.isel(time=1).to_dataframe()
# df2 = rfPlantbasedfibres.isel(time=2).to_dataframe()
# df3 = rfPlantbasedfibres.isel(time=3).to_dataframe()
# df4 = rfPlantbasedfibres.isel(time=4).to_dataframe()
# df5 = rfPlantbasedfibres.isel(time=5).to_dataframe()
# df6 = rfPlantbasedfibres.isel(time=6).to_dataframe()
# df7 = rfPlantbasedfibres.isel(time=7).to_dataframe()
# df8 = rfPlantbasedfibres.isel(time=8).to_dataframe()
# df9 = rfPlantbasedfibres.isel(time=9).to_dataframe()
# df10 = rfPlantbasedfibres.isel(time=10).to_dataframe()

table = pd.pivot_table(df, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
table1 = pd.pivot_table(df1, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table2 = pd.pivot_table(df2, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table3 = pd.pivot_table(df3, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table4 = pd.pivot_table(df4, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table5 = pd.pivot_table(df5, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table6 = pd.pivot_table(df6, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table7 = pd.pivot_table(df7, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table8 = pd.pivot_table(df8, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table9 = pd.pivot_table(df9, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)
# table10 = pd.pivot_table(df10, index=["country"], columns=['time'], aggfunc="sum", fill_value=0)

df_index = table.stack(level=0, future_stack=True ) # type: ignore
df_index1 = table1.stack(level=0, future_stack=True )# type: ignore
# df_index2 = table2.stack(level=0, future_stack=True )# type: ignore
# df_index3 = table3.stack(level=0, future_stack=True )# type: ignore
# df_index4 = table4.stack(level=0, future_stack=True )# type: ignore
# df_index5 = table5.stack(level=0, future_stack=True )# type: ignore
# df_index6 = table6.stack(level=0, future_stack=True )# type: ignore
# df_index7 = table7.stack(level=0, future_stack=True )# type: ignore
# df_index8 = table8.stack(level=0, future_stack=True )# type: ignore
# df_index9 = table9.stack(level=0, future_stack=True )# type: ignore
# df_index10 = table10.stack(level=0, future_stack=True )# type: ignore

data = pd.to_datetime(df_index.columns, format='%d/%m/%Y %H.%M.%S')
df_index.columns = data.year
data1 = pd.to_datetime(df_index1.columns, format='%d/%m/%Y %H.%M.%S')
df_index1.columns = data1.year
# data2 = pd.to_datetime(df_index2.columns, format='%d/%m/%Y %H.%M.%S')
# df_index2.columns = data2.year
# data3 = pd.to_datetime(df_index3.columns, format='%d/%m/%Y %H.%M.%S')
# df_index3.columns = data3.year
# data4 = pd.to_datetime(df_index4.columns, format='%d/%m/%Y %H.%M.%S')
# df_index4.columns = data4.year
# data5 = pd.to_datetime(df_index5.columns, format='%d/%m/%Y %H.%M.%S')
# df_index5.columns = data5.year
# data6 = pd.to_datetime(df_index6.columns, format='%d/%m/%Y %H.%M.%S')
# df_index6.columns = data6.year
# data7 = pd.to_datetime(df_index7.columns, format='%d/%m/%Y %H.%M.%S')
# df_index7.columns = data7.year
# data8 = pd.to_datetime(df_index8.columns, format='%d/%m/%Y %H.%M.%S')
# df_index8.columns = data8.year
# data9 = pd.to_datetime(df_index9.columns, format='%d/%m/%Y %H.%M.%S')
# df_index9.columns = data9.year
# data10 = pd.to_datetime(df_index10.columns, format='%d/%m/%Y %H.%M.%S')
# df_index10.columns = data10.year

df_index = df_index.reset_index()
df_index1 = df_index1.reset_index()
# df_index2 = df_index2.reset_index()
# df_index3 = df_index3.reset_index()
# df_index4 = df_index4.reset_index()
# df_index5 = df_index5.reset_index()
# df_index6 = df_index6.reset_index()
# df_index7 = df_index7.reset_index()
# df_index8 = df_index8.reset_index()
# df_index9 = df_index9.reset_index()
# df_index10 = df_index10.reset_index()

df_index.rename(columns={'level_1': "type"}, inplace=True)
df_index1.rename(columns={'level_1': "type"}, inplace=True)
# df_index2.rename(columns={'level_1': "type"}, inplace=True)
# df_index3.rename(columns={'level_1': "type"}, inplace=True)
# df_index4.rename(columns={'level_1': "type"}, inplace=True)
# df_index5.rename(columns={'level_1': "type"}, inplace=True)
# df_index6.rename(columns={'level_1': "type"}, inplace=True)
# df_index7.rename(columns={'level_1': "type"}, inplace=True)
# df_index8.rename(columns={'level_1': "type"}, inplace=True)
# df_index9.rename(columns={'level_1': "type"}, inplace=True)
# df_index10.rename(columns={'level_1': "type"}, inplace=True)

# frames = [df_index, df_index1, df_index2, df_index3, df_index4, df_index5, df_index6, df_index7, df_index8, df_index9, df_index10]
frames = [df_index, df_index1]
# Gabungkan semua DataFrame secara berurutan menggunakan reduce()
rfPlantbasedfibres_df = reduce(lambda left, right: pd.merge(left, right, on=["country", "type"]), frames)
rfPlantbasedfibres_df = rfPlantbasedfibres_df.replace([np.inf, -np.inf], np.nan)
rfPlantbasedfibres_df = rfPlantbasedfibres_df.fillna(0)

# %%
with pd.ExcelWriter("D:/kerja/asisten riset/vol/milkunC/achaidir/IMAGE PBL/SSP2/GFRAC_area_2thn.xlsx", engine='xlsxwriter') as writer:
    irWheat_df.to_excel(writer, sheet_name="IR Wheat", index=False)
    rfWheat_df.to_excel(writer, sheet_name="RF Wheat", index=False)
    irRice_df.to_excel(writer, sheet_name="IR Rice", index=False)
    rfRice_df.to_excel(writer, sheet_name="RF Rice", index=False)
    irMaize_df.to_excel(writer, sheet_name="IR Maize", index=False)
    rfMaize_df.to_excel(writer, sheet_name="RF Maize", index=False)
    irTropical_cereals_df.to_excel(writer, sheet_name="IR Tropical cereals", index=False)
    rfTropical_cereals_df.to_excel(writer, sheet_name="RF Tropical cereals", index=False)
    irOthertemperatecereals_df.to_excel(writer, sheet_name="IR Other temperate cereals", index=False)
    rfOthertemperatecereals_df.to_excel(writer, sheet_name="RF Other temperate cereals", index=False)
    irPulses_df.to_excel(writer, sheet_name="IR Pulses", index=False)
    rfPulses_df.to_excel(writer, sheet_name="RF Pulses", index=False)
    irSoybeans_df.to_excel(writer, sheet_name="IR Soybeans", index=False)
    rfSoybeans_df.to_excel(writer, sheet_name="RF Soybeans", index=False)
    irTemperateoilcrops_df.to_excel(writer, sheet_name="IR Temperate oil crops", index=False)
    rfTemperateoilcrops_df.to_excel(writer, sheet_name="RF Temperate oil crops", index=False)
    irTropicaloilcrops_df.to_excel(writer, sheet_name="IR Tropical oil crops", index=False)
    rfTropicaloilcrops_df.to_excel(writer, sheet_name="RF Tropical oil crops", index=False)
    irTemperaterootstubers_df.to_excel(writer, sheet_name="IR Temperate roots & tubers", index=False)
    rfTemperaterootstubers_df.to_excel(writer, sheet_name="RF Temperate roots & tubers", index=False)
    irTropicalrootstubers_df.to_excel(writer, sheet_name="IR Tropical roots & tubers", index=False)
    rfTropicalrootstubers_df.to_excel(writer, sheet_name="RF Tropical roots & tubers", index=False)
    irSugarcrops_df.to_excel(writer, sheet_name="IR Sugar crops", index=False)
    rfSugarcrops_df.to_excel(writer, sheet_name="RF Sugar crops", index=False)
    irOilpalmfruit_df.to_excel(writer, sheet_name="IR Oil & palm fruit", index=False)
    rfOilpalmfruit_df.to_excel(writer, sheet_name="RF Oil & palm fruit", index=False)
    irVegetablesfruits_df.to_excel(writer, sheet_name="IR Vegetables & fruits", index=False)
    rfVegetablesfruits_df.to_excel(writer, sheet_name="RF Vegetables & fruits", index=False)
    irOthernonfooduxuryspices_df.to_excel(writer, sheet_name="IR Othernon-food&luxury spices", index=False)
    rfOthernonfooduxuryspices_df.to_excel(writer, sheet_name="RF Othernon-food&luxury spices", index=False)
    irPlantbasedfibres_df.to_excel(writer, sheet_name="IR Plant based fibres", index=False)
    rfPlantbasedfibres_df.to_excel(writer, sheet_name="RF Plant based fibres", index=False)
