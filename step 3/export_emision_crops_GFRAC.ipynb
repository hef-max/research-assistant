# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:/kerja/asisten riset/vol/milkunC/achaidir/FAO/luc_agri_prop_crop_AM1.xlsx")
df.head()
# Out:
#   country_name                              type      1975      1980  \
# 0  Afghanistan                             grass  0.001373  0.000105
# 1  Afghanistan                             maize  0.000141  0.000104
# 2  Afghanistan                  oil & palm fruit  0.000071  0.000206
# 3  Afghanistan  other non-food & luxury & spices  0.000072  0.000173
# 4  Afghanistan           other temperate cereals  0.000108  0.000118
#
#        1985      1990      1995          2000      2005      2010      2015  \
# 0  0.001068  0.000016  0.000204  1.235389e-03  0.000007  0.000296  0.001582
# 1  0.000006  0.000117  0.000078  5.830169e-07  0.000006  0.000277  0.000033
# 2  0.000010  0.000124  0.000284  1.899163e-07  0.000629  0.000081  0.000144
# 3  0.000017  0.000157  0.000309  2.846773e-06  0.000618  0.000069  0.000149
# 4  0.000004  0.000101  0.000070  7.945947e-07  0.000005  0.000242  0.000037
#
#            2020
# 0  2.222766e-04
# 1  0.000000e+00
# 2  0.000000e+00
# 3  5.388171e-09
# ...

# %%
columns = df.columns[2:].to_list()
df_pivot = df.pivot_table(columns='type', values=columns, aggfunc="sum")
df_pivot.head()
# Out:
# type     grass     maize  oil & palm fruit  other non-food & luxury & spices  \
# 1975  1.621505  0.292491          0.027714                          0.401965
# 1980  1.026135  0.315228          0.049345                          0.423800
# 1985  1.180142  0.121473          0.009968                          0.391185
# 1990  0.979959  0.115693          0.084205                          1.017805
# 1995  1.002970  0.314375          0.019633                          0.952383
#
# type  other temperate cereals  plant based fibres    pulses      rice  \
# 1975                 0.504701            0.035019  0.264926  1.181528
# 1980                 4.873539            0.066853  0.270767  1.190321
# 1985                 0.022648            0.013251  0.270179  1.224290
# 1990                 0.010406            0.084640  0.260728  1.202711
# 1995                 0.044772            0.023882  0.299276  1.246440
#
# type  soybeans  sugar crops  temperate oil crops  temperate roots & tubers  \
# ...

# %%
df_pivot = df_pivot.reset_index()

# %%
df_pivot = df_pivot.rename(columns={"index" : "time"})

# %%
df_pivot.to_excel("D:/kerja/asisten riset/code v/step 3/GbGlct/luc_agri_prop_crop_AM1_chart1.xlsx", index=False)

# %%
ccode_iso = pd.read_excel("D:/kerja/asisten riset/vol/milkunC/achaidir/LUH2 2022/ISO-3166-Country-Code_REV.xlsx", sheet_name="Sheet3")

# %%
df_merge = pd.merge(left=df, right=ccode_iso, how="left", left_on="country_name", right_on="Country")
df_merge.head()
# Out:
#   country_name                              type      1975      1980  \
# 0  Afghanistan                             grass  0.001373  0.000105
# 1  Afghanistan                             maize  0.000141  0.000104
# 2  Afghanistan                  oil & palm fruit  0.000071  0.000206
# 3  Afghanistan  other non-food & luxury & spices  0.000072  0.000173
# 4  Afghanistan           other temperate cereals  0.000108  0.000118
#
#        1985      1990      1995          2000      2005      2010      2015  \
# 0  0.001068  0.000016  0.000204  1.235389e-03  0.000007  0.000296  0.001582
# 1  0.000006  0.000117  0.000078  5.830169e-07  0.000006  0.000277  0.000033
# 2  0.000010  0.000124  0.000284  1.899163e-07  0.000629  0.000081  0.000144
# 3  0.000017  0.000157  0.000309  2.846773e-06  0.000618  0.000069  0.000149
# 4  0.000004  0.000101  0.000070  7.945947e-07  0.000005  0.000242  0.000037
#
#            2020      Country Region   SubRegion
# ...

# %%
columns.append("SubRegion")
columns.append("type")
df_subregion = df_merge[columns]
df_merge_groupby = df_subregion.groupby('SubRegion').sum()
df_merge_groupby.head()
# Out:
#                        1975      1980      1985      1990      1995      2000  \
# SubRegion
# East Asia          0.824334  1.241812  0.676433  0.686857  0.695975  2.054011
# Europe and Russia  0.129207  0.425688  0.298152  0.352896  0.459051  0.173684
# Latin America      3.813854  7.885457  6.886220  7.215719  6.222258  4.558812
# Middle East        0.037621  0.056631  0.038289  0.040704  0.052658  0.037327
# North America      0.109407  0.068343  0.108697  0.208030  0.170466  0.084550
#
#                        2005      2010      2015      2020  \
# SubRegion
# East Asia          0.639389  0.513009  0.563346  0.495840
# Europe and Russia  0.134517  0.186135  0.107963  0.028667
# Latin America      3.059246  3.250531  3.427992  3.143155
# Middle East        0.044026  0.037448  0.028388  0.009599
# North America      0.092654  0.107924  0.078767  0.008512
#
#                                                                 type
# SubRegion
# ...

# %%
df_merge_groupby = df_merge_groupby.reset_index()
df_merge_groupby = df_merge_groupby.drop(columns=["type"])
df_merge_groupby.head()
# Out:
#            SubRegion      1975      1980      1985      1990      1995  \
# 0          East Asia  0.824334  1.241812  0.676433  0.686857  0.695975
# 1  Europe and Russia  0.129207  0.425688  0.298152  0.352896  0.459051
# 2      Latin America  3.813854  7.885457  6.886220  7.215719  6.222258
# 3        Middle East  0.037621  0.056631  0.038289  0.040704  0.052658
# 4      North America  0.109407  0.068343  0.108697  0.208030  0.170466
#
#        2000      2005      2010      2015      2020
# 0  2.054011  0.639389  0.513009  0.563346  0.495840
# 1  0.173684  0.134517  0.186135  0.107963  0.028667
# 2  4.558812  3.059246  3.250531  3.427992  3.143155
# 3  0.037327  0.044026  0.037448  0.028388  0.009599
# 4  0.084550  0.092654  0.107924  0.078767  0.008512

# %%
# columns2 = df_merge_groupby.columns[2:].to_list()

# %%
# df_merge_groupby_pivot = df_merge_groupby.pivot_table(columns='type', values=columns2, index="SubRegion", aggfunc="sum")
# df_merge_groupby_pivot.head()
# Out:
#                        1975                             \
# type                  grass     maize oil & palm fruit
# SubRegion
# East Asia          0.083331  0.001738         0.001061
# Europe and Russia  0.016071  0.002980         0.006924
# Latin America      0.782839  0.010473         0.000251
# Middle East        0.004302  0.001928         0.001509
# North America      0.009281  0.004005         0.006373
#
#                                                                             \
# type              other non-food & luxury & spices other temperate cereals
# SubRegion
# East Asia                                 0.005834                0.092655
# Europe and Russia                         0.008842                0.005522
# Latin America                             0.233075                0.341993
# Middle East                               0.001569                0.002398
# North America                             0.004440                0.003663
#
# ...

# %%
# df_merge_groupby_pivot_index = df_merge_groupby_pivot.stack(level=0, future_stack=True ) # type: ignore
# df_merge_groupby_pivot_index = df_merge_groupby_pivot_index.reset_index()

# %%
# df_merge_groupby_pivot_index.rename(columns={'level_1': "time"}, inplace=True)
# df_merge_groupby_pivot_index.head()
# Out:
# type  SubRegion  time     grass     maize  oil & palm fruit  \
# 0     East Asia  1975  0.083331  0.001738          0.001061
# 1     East Asia  1980  0.078381  0.001067          0.000564
# 2     East Asia  1985  0.081519  0.004647          0.000275
# 3     East Asia  1990  0.077014  0.000811          0.004390
# 4     East Asia  1995  0.077986  0.012453          0.002239
#
# type  other non-food & luxury & spices  other temperate cereals  \
# 0                             0.005834                 0.092655
# 1                             0.005791                 0.101129
# 2                             0.005111                 0.004087
# 3                             0.005138                 0.000571
# 4                             0.002172                 0.004005
#
# type  plant based fibres    pulses      rice  soybeans  sugar crops  \
# 0               0.001310  0.003372  0.307901  0.005191     0.001029
# 1               0.000860  0.001040  0.310545  0.001132     0.000589
# ...

# %%
# df_merge_groupby_pivot_groupby = df_merge_groupby_pivot_index.groupby("SubRegion").sum()
# df_merge_groupby_pivot_groupby.head()

# %%
# tahun = list(range(1975, 2025, 5))
# df_merge_groupby_pivot_groupby = df_merge_groupby_pivot_index.groupby("SubRegion").sum()
# df_merge_groupby_pivot_groupby = df_merge_groupby_pivot_groupby.drop(columns=["type"])
# df_merge_groupby_pivot_groupby = df_merge_groupby_pivot_groupby.reset_index()
# df_merge_groupby_pivot_groupby.head()
# Out:
# time          SubRegion        1975        1980         1985         1990  \
# 0             East Asia   70.815856   69.833397  1125.136949  2005.070517
# 1     Europe and Russia  163.102030  137.799981   133.374219   177.891342
# 2         Latin America  521.914832  436.668303   408.049831  1708.812800
# 3           Middle East   40.524231   36.254861    35.288182    32.531414
# 4         North America  161.938875  131.627214   138.018707   156.686634
#
# time         1995         2000         2005        2010         2015  \
# 0     1452.712414  1114.139551   499.160007  236.049049   290.953615
# 1      189.637765   205.518637   217.352501  123.350713   148.914713
# 2     1817.242511  1831.165576  1638.982399  889.557900  1190.443254
# 3       33.213698    33.364455    35.234840   34.437943    34.741460
# 4      169.695496   185.423773   164.500314  118.535780   113.583392
#
# time         2020
# 0      285.536115
# 1      140.899868
# 2     1196.228468
# 3       36.247658
# ...

# %%
df_merge_groupby.to_excel("D:/kerja/asisten riset/code v/step 3/GbGlct/luc_agri_prop_crop_AM1_chart2.xlsx", index=False)
